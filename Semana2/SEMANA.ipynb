# %%
calificacion = 78
conducta = 10 
if calificacion >= 90:
    print ("A")
elif calificacion >= 80:
    print ("B")
elif calificacion >= 78:
    print ("C") 
elif calificacion >= 60:
    print ("D")
else: 
    print ("E")
# Out:
# C

# %%
PL1 = not True
PL2 = False

print (PL1 or PL2)
# Out:
# False

# %%
edad = 85
tipo = "adulto_mayor"

es_mayor = edad >=18
print (es_mayor)
aplica_descuento = (edad >= 60) and (tipo >= "adulto mayor")
print (aplica_descuento)
# Out:
# True
# True

# %%
edad = int(input("ingresa tu edad"))

if (edad < 0):
    print ("agunta, no hay edades menores a 0")

else:
    print ("Ahora si vamos a trabajar con edades reales")
# Out:
# Ahora si vamos a trabajar con edades reales

# %%
precio = 30
if tipo == "adulto_mayor":
    descuento = precio * 0.10       
elif tipo == "profesor" or tipo == "estudiante":
    descuento = precio * 0.50        
else:
    descuento = 0
total = precio - descuento
print (f"Total a pagar: ${total:.2f}")
# Out:
# Total a pagar: $27.00

# %%
numero = int(input("ingresa un numero entero: "))
if (numero % 2 == 0):
    print ("es un numero par")
else: 
    print ("no es un numero entero")
# Out:
# es un numero par

# %%
numero = int(input("ingresa tu calificacion: "))
if (numero >= 6):
    print ("aprobaste")
else:
    print ("reprobaste")
# Out:
# aprobaste

# %%
numero = int(input("ingresa su edad: "))
if (numero <= 3):       
    print ("es un bebe")    
if (numero > 3 and numero <= 12):    
    print ("es un niño")
if (numero > 12 and numero <= 18):
    print ("es un adolescente")
if (numero >= 18):
    print ("es un adulto")
# Out:
# es un adulto

# %%
visitante = input("ingresa tu tipo de visitante: ")

precio = 45

if visitante == "adulto_mayor":
    descuento = precio * 0.12
elif visitante == "adulto_mayor" or visitante == "estudiante":
    descuento = precio * 0.10
else:
    visitante == "pasajero normal"
    descuento = 0

total = precio - descuento 

print (f"Total a pagar: ${total:.2f}")
# Out:
# Total a pagar: $40.50

# %%
tabla = int(input("ingresa un numero entero para ver su tabla de multiplicar: "))

for n in range(100):
    # print (f"{tabla} x {n} = {tabla * n}")    
    print (tabla, "x", n, "=", tabla * n)
# Out:
# 10 x 0 = 0
# 10 x 1 = 10
# 10 x 2 = 20
# 10 x 3 = 30
# 10 x 4 = 40
# 10 x 5 = 50
# 10 x 6 = 60
# 10 x 7 = 70
# 10 x 8 = 80
# 10 x 9 = 90
# 10 x 10 = 100
# 10 x 11 = 110
# 10 x 12 = 120
# 10 x 13 = 130
# 10 x 14 = 140
# 10 x 15 = 150
# 10 x 16 = 160
# 10 x 17 = 170
# 10 x 18 = 180
# 10 x 19 = 190
# 10 x 20 = 200
# 10 x 21 = 210
# 10 x 22 = 220
# 10 x 23 = 230
# 10 x 24 = 240
# 10 x 25 = 250
# 10 x 26 = 260
# 10 x 27 = 270
# 10 x 28 = 280
# 10 x 29 = 290
# 10 x 30 = 300
# 10 x 31 = 310
# 10 x 32 = 320
# 10 x 33 = 330
# 10 x 34 = 340
# 10 x 35 = 350
# 10 x 36 = 360
# 10 x 37 = 370
# 10 x 38 = 380
# 10 x 39 = 390
# 10 x 40 = 400
# 10 x 41 = 410
# 10 x 42 = 420
# 10 x 43 = 430
# 10 x 44 = 440
# 10 x 45 = 450
# 10 x 46 = 460
# 10 x 47 = 470
# 10 x 48 = 480
# 10 x 49 = 490
# 10 x 50 = 500
# 10 x 51 = 510
# 10 x 52 = 520
# 10 x 53 = 530
# 10 x 54 = 540
# 10 x 55 = 550
# 10 x 56 = 560
# 10 x 57 = 570
# 10 x 58 = 580
# 10 x 59 = 590
# 10 x 60 = 600
# 10 x 61 = 610
# 10 x 62 = 620
# ...

# %%
personas = int(input("Cuantas personas son :"))
edad_acumulada = 0

for p in range (1, personas +1):
    edad_personas = int(input(f"Dame la edad de la persona (p)"))
    edad_acumulada = edad_acumulada + edad_personas
    print (f"su edad acumulada es (edad_acumulada)")

print ("fin del programa")
# Out:
# su edad acumulada es (edad_acumulada)
# su edad acumulada es (edad_acumulada)
# fin del programa

# %%
precio = 45
descuento = precio * 0.12
total = precio - descuento
print(f"Total a pagar: ${total:.2f}")
# Out:
# Total a pagar: $39.60

# %%
edad = int(input("ingresa tu edad: "))

if edad >= 18:

    print ("puedes entrar")
else:
    print ("no puedes entrar")
# Out:
# no puedes entrar

# %%
edad = int(input("ingresa tu edad: "))

tipo = "adulto_mayor"

es_mayor = edad >=18
aplica_descuento = (edad >= 60) and tipo == "adulto_mayor"

no_es_estudiante = not (tipo == "estudiante")

print ("ustded es mayor de edad:", es_mayor)
print ("aplica descuento:", aplica_descuento)
print ("no es estudiante:", no_es_estudiante)
# Out:
# ustded es mayor de edad: True
# aplica descuento: False
# no es estudiante: True
