# %% [markdown]
# ## Entrada De Museo
#
# ## 2. Requerimientos técnicos obligatorios
# 1. **Captura de visitantes:** El usuario debe poder ingresar el número total de
# visitantes que pagarán boleto, si son mayores de edad y el tipo de visitante de
# cada uno.
# 2. **Tabla de verdad de descuentos:** La matriz de descuentos debe estar
# estructurada lógicamente como una **tabla de verdad**, de modo que **solo se
# aplique un tipo de descuento por boleto** (adulto mayor 12%, profesor 10%,
# estudiante 10%).
# 3. **Ciclo controlado:** Se debe implementar un ciclo controlado (`for` o `while`)
# para procesar a los visitantes.
# 4. **`break` y `continue` obligatorios:** Dentro del ciclo es obligatorio el uso de
# **al menos una cláusula `break`** y **al menos una cláusula `continue`**.
# 5. **Total detallado:** El programa debe desplegar el total detallado a pagar de
# todas las personas ingresadas, considerando sus descuentos aplicables **de forma
# indivi

# %%
visitantes = int(input("Cuantas personas son:"))

i = 0
total = 0
i = i + 1       

for i in range (1, visitantes + 1): 

    edad = int(input(f"Cuantos años tiene cada uno {i}:"))
    tipo = input("Quien viaja: ")

if edad <= 3:
    precio = 0
elif edad <= 17:
    precio = 30
else:
    edad <= 18
    precio = 45
if tipo == "adulto_mayor":
    descuento_3= precio * 0.12   
elif tipo == "profesor" or tipo == "estudiante":
    descuento_2= precio * 0.10
elif tipo == "bebe":
    descuento_1= 0

else: 
    precio = precio 


descuento = precio - descuento_1
total_grupo = descuento * visitantes


print (f"Total a pagar: ${descuento:.2f}")
print (f"Total a pagar por el grupo ({visitantes}): ${total_grupo:.2f}")
# Out:
# Total a pagar: $45.00
# Total a pagar por el grupo (2): $90.00

# %% [markdown]
# ## EJERCICIO EXTRA 1
# ## Control de aforo con break y continue (while)
# **Enunciado:** Crea un programa que procese visitantes del museo con un ciclo
# `while`. Por cada visitante se captura el costo de su boleto ($0 para menores de 3
# años, $30 para 3 a 17 años, $45 para mayores de 18). Si el boleto es gratis,
# muestra "Menor de 3 años, sin cargo" y continúa con el siguiente visitante (usa
# `continue`). Si el total acumulado alcanza o supera $100, detén el ciclo con
# `break

# %%
total = 0
i = 1

while True:

    boleto = float(input(f"boleto del boleto {i}: "))

    if boleto == 0:
        print("Menor de 3 años, sin cargo")
        i = i + 1
        continue

    total = total + boleto
    i = i + 1

    if total >= 100:
        print("total alcanzado")
        break

print(f"Total: ${total:.2f}")
# Out:
# total alcanzado
# Total: $120.00

# %% [markdown]
# ## EJERCICIO EXTRA 2
# ## Estadística de visitantes con for
# **Enunciado:** Crea un programa que pida el número total de visitantes y, con un
# ciclo `for`, capture la edad de cada uno. Debe contar cuántos son adultos (18 años
# o más) y calcular el promedio de edad de todos los visitantes, mostrando ambos
# resultad

# %%
total_visitantes = int(input("Número de visitantes: "))

adultos = 0
suma_edades = 0

for i in range(1, total_visitantes + 1):

    edad = int(input(f"Edad del visitante {i}: "))

    suma_edades = suma_edades + edad

    if edad >= 18:
        adultos = adultos + 1

promedio = suma_edades / total_visitantes

print(f"Adultos: {adultos}", f"Promedio de edad: {promedio:.2f}")
# Out:
# Adultos: 1 Promedio de edad: 14.00

# %% [markdown]
# ## EJERCICIO EXTRA 3
# ## Depuración de un cobro con PDB
# **Enunciado:** El siguiente código pretende calcular el precio final de un boleto
# de $45 con el descuento del adulto mayor (12%) pero contiene un error de lógica.
# Inserta `pdb.set_trace()` para rastrear las variables, identifica el error y
# escribe

# %%
#import pdb
#pdb.set_trace()
precio = 45
descuento = precio * 0.12
total = precio - descuento
print(f"Total a pagar: ${total:.2f}")
# Out:
# Total a pagar: $39.60

# %% [markdown]
# ## EJERCICIO EXTRA 4
# ## Pirámide de asteriscos con for
# **Enunciado:** Crea un programa que pida la altura de una pirámide y la dibuje con
# asteriscos usando

# %%
for i in range (1,5):
    print ("*" * i)

print ()
# Out:
# *
# **
# ***
# ****
