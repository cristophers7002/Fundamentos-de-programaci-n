# %%
archivo = open("saludo.txt", mode="a")

archivo.write("est liena\n")

archivo.close()

print ("Se ha escrito mi archivo.txt")
# Out:
# Se ha escrito mi archivo.txt

# %%
with open("bitacora.txt", mode="w") as archivo:
    archivo.write("Esto es una primera liena\n")
    archivo.write("Esto es uan segunda liena\n")
    archivo.write("Esto es. una tercera liena\n")

with open("bitacora.txt", mode="a") as archivo:
    archivo.write ("Esto es una cuarta linea\n")

# %%
nombre = input("ingresa su nombre:")
edad = input("ingrese su edad:")

with open("datos_usuarios.txt", mode="w") as archivo:
    archivo.write(f"nombre: {nombre}, edad: {edad}\n")

print ("Datos gaurdados")
# Out:
# Datos gaurdados

# %%
with open ("saludo.txt", mode="w") as archivo:
    archivo.write ("Hola, mundo\n")

archivo.close ()
